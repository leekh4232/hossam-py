# %%
from hossam import *

# %%
# hs_classroom을 사용한 조편성 (5개 조로 구분)
result = hs_classroom.analyze_classroom(
    df="students.csv",
    n_groups=5,
    score_cols=["과목1점수", "과목2점수", "과목3점수", "과목4점수", "과목5점수"],
    interest_col="관심사",
    score_metric="average",  # 평균 점수 기준
)

result
# Out:
# ✓ 조 편성 완료: 30명의 학생을 5개 조로 배정
#    조                            학생    총점평균  평균점수평균
# 0  0                 S21, S22, S23  194.67   38.93
# 1  1  S04, S10, S14, S26, S28, S29  386.67   77.33
# 2  2  S03, S07, S08, S09, S12, S30  389.00   77.80
# 3  3       S01, S11, S16, S20, S27  412.20   82.44
# 4  4       S02, S06, S15, S19, S24  421.80   84.36
# 5  5       S05, S13, S17, S18, S25  396.80   79.36
