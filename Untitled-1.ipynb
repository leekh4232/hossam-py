# %%
from hossam.classroom import *

# %%
analyze_classroom(
    "students.csv",
    n_groups=5,
    score_cols=["과목1점수", "과목2점수", "과목3점수", "과목4점수", "과목5점수"],
    score_metric="average",
    interest_col="관심사",
    name_col="학생번호",
)
# Out:
# ...
# 1. 학생 조 편성 중...
# ...
#
# ✓ 조 편성 완료: 30명의 학생을 5개 조로 배정
#
# ...
# 2. 조별 요약 생성 중...
# ...
#
# ✓ 조별 요약:
# +---+----+------------------------------+----------+--------------+
# |   | 조 |             학생             | 총점평균 | 평균점수평균 |
# +---+----+------------------------------+----------+--------------+
# | 0 | 0  |        S21, S22, S23         |  194.67  |    38.93     |
# | 1 | 1  | S04, S10, S14, S26, S28, S29 |  386.67  |    77.33     |
# | 2 | 2  | S03, S07, S08, S09, S12, S30 |  389.0   |     77.8     |
# | 3 | 3  |   S01, S11, S16, S20, S27    |  412.2   |    82.44     |
# | 4 | 4  |   S02, S06, S15, S19, S24    |  421.8   |    84.36     |
# | 5 | 5  |   S05, S13, S17, S18, S25    |  396.8   |    79.36     |
# +---+----+------------------------------+----------+--------------+
#
# ...
# 3. 조 편성 요약 시각화 중...
# ...
# ✓ 요약 시각화 완료
#
# ...
# 4. 조별 average KDE 시각화 중...
# ...
# ✓ KDE 시각화 완료
#
# ...
# 전체 분석 완료!
# ...
#    조                            학생    총점평균  평균점수평균
# 0  0                 S21, S22, S23  194.67   38.93
# ...
