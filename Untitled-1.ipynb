# %%
from hossam.classroom import *

# %%
analyze_classroom(
    "students.csv",
    n_groups=5,
    score_cols=["과목1점수", "과목2점수", "과목3점수", "과목4점수", "과목5점수"],
    score_metric="average",
    name_col="학생번호",
)
# Out:
# ...
# 1. 학생 조 편성 중...
# ...
#
# ✓ 조 편성 완료: 30명의 학생을 5개 조로 배정
#
# ...
# 2. 조별 요약 생성 중...
# ...
#
# ✓ 조별 요약:
# +---+----+------------------------------+----------+--------------+
# |   | 조 |             학생             | 총점평균 | 평균점수평균 |
# +---+----+------------------------------+----------+--------------+
# | 0 | 0  |        S21, S22, S23         |  194.67  |    38.93     |
# | 1 | 1  |   S01, S06, S11, S16, S26    |  390.2   |    78.04     |
# | 2 | 2  |   S02, S07, S12, S17, S27    |  408.8   |    81.76     |
# | 3 | 3  |   S03, S08, S13, S18, S28    |  384.8   |    76.96     |
# | 4 | 4  | S04, S09, S14, S19, S24, S29 |  406.67  |    81.33     |
# | 5 | 5  | S05, S10, S15, S20, S25, S30 |  408.17  |    81.63     |
# +---+----+------------------------------+----------+--------------+
#
# ...
# 3. 조 편성 요약 시각화 중...
# ...
# ✓ 요약 시각화 완료
#
# ...
# 4. 조별 average KDE 시각화 중...
# ...
# ✓ KDE 시각화 완료
#
# ...
# 전체 분석 완료!
# ...
#    조                            학생    총점평균  평균점수평균
# 0  0                 S21, S22, S23  194.67   38.93
# ...
